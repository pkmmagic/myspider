# %%
headers = {
'User-Agent': 'Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/49.0.2623.221 Safari/537.36 SE 2.X MetaSr 1.0',
'Cookie':'a22e7_c_stamp=1533181577; a22e7_readlog=%2C98009%2C; a22e7_lastpos=F21; a22e7_ol_offset=158886; visid_incap_1639104=Jb5ILxvzTxmJ4cESKs8iTqZ6YlsAAAAAQUIPAAAAAAAAjBuqYIiX7PR9wNyLyeP9; incap_ses_895_1639104=VXOzBLM33Dl3ZuyUKK5rDOOYYlsAAAAAiqUCEpEAatms3yseNcrw/g==; a22e7_lastvisit=220%091533188333%09%2F2048%2Fthread.php%3Ffid-21.html; a22e7_threadlog=%2C21%2C'
}
import requests, urllib.request, myspider, time 
from bs4 import BeautifulSoup
from urllib.request import urlopen

since = time.time()
LibPath, NewPath = 'd:\\img\\2.txt', 'd:\\img\\3.txt'

#url = 'http://www.weiai2048.com/2048/thread.php?fid-21-page-144.html'
#url = 'http://www.weiai2048.com/2048/thread.php?fid-24.html'
subpage_url_num_set = set()
for i in range(170,180):
    try:
        url = 'http://www.weiai2048.com/2048/thread.php?fid-21-page-'+str(i)+'.html'
        result = urlopen(urllib.request.Request(url,headers=headers), timeout=30)
        soup = BeautifulSoup(result,'html.parser')
        myspider.get_num_set5(soup,subpage_url_num_set)
    except Exception as e:
        pass
print(subpage_url_num_set)

All_set = set()
myspider.open2add(LibPath,All_set)
diff = subpage_url_num_set.difference(All_set)
myspider.open2w(NewPath,list(diff))

print(str(len(subpage_url_num_set))+' get and '+ str(len(diff))+ ' new numbers')

All_set.update(diff)
myspider.open2w(LibPath,sorted(list(All_set)))
time_elapsed = time.time() - since
print (time_elapsed)
# Out:
# {'62023', '64315', '63967', '65611', '65550', '60327', '61999', '60348', '65623', '65539', '63977', '60386', '61951', '65592', '63987', '62004', '66881', '60285', '63985', '60404', '66496', '63950', '66888', '62032', '61992', '60301', '61978', '63996', '65520', '65519', '63966', '63964', '63930', '63915', '61958', '66883', '65557', '63922', '65565', '65535', '62074', '62015', '63911', '63992', '63961', '61989', '64302', '60385', '66886', '61979', '66878', '64474', '61942', '62045', '65574', '61987', '60351', '60344', '65543', '65618', '66508', '63938', '66895', '62009', '61964', '61936', '65627', '65589', '64282', '65547', '61929', '64298', '61956', '63945', '64467', '61986', '62049', '65591', '65616', '63981', '63994', '66875', '60398', '65558', '61937', '62063', '66504', '62006', '60345', '60298', '60375', '65530', '61994', '60331', '62022', '63902', '64420', '65575', '60283', '61963', '63931', '63973', '63913', '61966', '65518', '60418', '65590', '63908', '63969', '63968', '66966'
# ...

# %%
headers = {
'User-Agent': 'Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/49.0.2623.221 Safari/537.36 SE 2.X MetaSr 1.0',
'Cookie':'a22e7_c_stamp=1533181577; a22e7_readlog=%2C98009%2C; a22e7_lastpos=F21; a22e7_ol_offset=158886; visid_incap_1639104=Jb5ILxvzTxmJ4cESKs8iTqZ6YlsAAAAAQUIPAAAAAAAAjBuqYIiX7PR9wNyLyeP9; incap_ses_895_1639104=VXOzBLM33Dl3ZuyUKK5rDOOYYlsAAAAAiqUCEpEAatms3yseNcrw/g==; a22e7_lastvisit=220%091533188333%09%2F2048%2Fthread.php%3Ffid-21.html; a22e7_threadlog=%2C21%2C'
}
import requests, urllib.request, myspider, time 
from bs4 import BeautifulSoup
from urllib.request import urlopen

UrlPath, ErPath, NewPath = 'd:\\img\\1.txt', 'd:\\img\\4.txt', 'd:\\img\\3.txt'

image_url_list,error_list = [],[]
num_set = set()
myspider.open2add(NewPath,num_set)
myspider.open2add(ErPath,num_set)
num_list = list(num_set)

def get_url(num):
    req = urllib.request.Request('http://www.weiai2048.com/2048/read.php?tid-' + num + '.html',headers=headers)
    result = urlopen(req, timeout=45)
    soup2 = BeautifulSoup(result,'html.parser')
    myspider.get_list(soup2,image_url_list)
    print(num +' done')

for num in num_list:
    try:
        since=time.time()
        get_url(num)
        time_elapsed = time.time() - since
        print(str(num_list.index(num))+': '+str(time_elapsed))
    except Exception as e:
        error_list.append(num)
        
print(len(image_url_list))

myspider.open2a(UrlPath,image_url_list)
myspider.open2w(ErPath,error_list)
# Out:
# 62023 done
# 0: 6.769999980926514
# 64315 done
# 1: 4.506999969482422
# 63967 done
# 2: 2.809000015258789
# 65611 done
# 3: 5.583999872207642
# 65550 done
# 4: 6.957000255584717
# 60327 done
# 5: 16.068000078201294
# 61999 done
# 6: 4.985999822616577
# 60348 done
# 7: 24.867000102996826
# 65623 done
# 8: 3.4609999656677246
# 65539 done
# 9: 5.497999906539917
# 63977 done
# 10: 6.322000026702881
# 60386 done
# 11: 7.744999885559082
# 61951 done
# 12: 3.9700000286102295
# 65592 done
# 13: 4.448000192642212
# 63987 done
# 14: 6.449999809265137
# 68814 done
# 15: 5.883000135421753
# 62004 done
# 16: 10.90999984741211
# 66881 done
# 17: 6.575000047683716
# 60285 done
# 18: 2.578000068664551
# 63985 done
# 19: 9.21399998664856
# 68383 done
# 20: 3.7209999561309814
# 60404 done
# 21: 2.9789998531341553
# 66496 done
# 22: 13.82800006866455
# 63950 done
# 23: 1.9940001964569092
# 66888 done
# 24: 4.228999853134155
# 62032 done
# 25: 3.7290000915527344
# 61992 done
# 26: 5.001000165939331
# ...
