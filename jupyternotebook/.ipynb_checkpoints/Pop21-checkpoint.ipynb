# %%
import myspider
image_url_list = []
#urlPath = 'd:\\img\\url23.txt'
urlPath = 'd:\\img\\1.txt'
myspider.open2append(urlPath,image_url_list)

def pop_1000():
    for i in range(1000):
        if len(image_url_list)>0:
            print(image_url_list.pop())
            
print(len(image_url_list))       

pop_1000()
print(len(image_url_list))
myspider.open2w(urlPath,image_url_list)
# Out:
# 32488
# http://p.usxpic.com/imghost/upload/image/20180219/21902175555.jpg
# http://p.usxpic.com/imghost/upload/image/20180219/21902175553.jpg
# http://p.usxpic.com/imghost/upload/image/20180219/21902175603.jpg
# http://p.usxpic.com/imghost/upload/image/20180219/21902175600.jpg
# http://p.usxpic.com/imghost/upload/image/20180219/21902175599.jpg
# http://p.usxpic.com/imghost/upload/image/20180219/21902175596.jpg
# http://p.usxpic.com/imghost/upload/image/20180219/21902175595.jpg
# http://p.usxpic.com/imghost/upload/image/20180219/21902175593.jpg
# http://p.usxpic.com/imghost/upload/image/20180219/21902175590.jpg
# http://p.usxpic.com/imghost/upload/image/20180219/21902175589.jpg
# http://p.usxpic.com/imghost/upload/image/20180219/21902175587.jpg
# http://p.usxpic.com/imghost/upload/image/20180219/21902175583.jpg
# http://p.usxpic.com/imghost/upload/image/20180219/21902175582.jpg
# http://p.usxpic.com/imghost/upload/image/20180219/21902175581.jpg
# ...
