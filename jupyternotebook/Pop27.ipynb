# %%
import myspider
#path = 'text6.txt'
#path = r'D:\py\spider\27\candidates.txt'
path = r'D:\py\spider\21\candidates.txt'

image_url_list = []
myspider.open2append(path,image_url_list)

def pop_1000():
    for i in range(1000):
        if len(image_url_list)>0:
            print(image_url_list.pop(0))
            
print(len(image_url_list))  

pop_1000()
print(len(image_url_list))

myspider.open2w(path,image_url_list)
# Out:
# 12488
# http://p3.urlpic.club/picturespace/upload/image/20180207/20709034384.jpg
# http://p3.urlpic.club/picturespace/upload/image/20180207/20709034388.jpg
# http://p3.urlpic.club/picturespace/upload/image/20180207/20709034393.jpg
# http://p3.urlpic.club/picturespace/upload/image/20180207/20709034395.jpg
# http://p3.urlpic.club/picturespace/upload/image/20180207/20709034398.jpg
# http://p3.urlpic.club/picturespace/upload/image/20180207/20709034400.jpg
# http://p3.urlpic.club/picturespace/upload/image/20180207/20709034402.jpg
# http://p3.urlpic.club/picturespace/upload/image/20180207/20709034404.jpg
# http://p3.urlpic.club/picturespace/upload/image/20180207/20709034406.jpg
# http://p3.urlpic.club/picturespace/upload/image/20180207/20709034408.jpg
# http://p3.urlpic.club/picturespace/upload/image/20180208/20810064952.jpg
# http://p3.urlpic.club/picturespace/upload/image/20180208/20810064958.jpg
# http://p3.urlpic.club/picturespace/upload/image/20180208/20810064964.jpg
# ...
