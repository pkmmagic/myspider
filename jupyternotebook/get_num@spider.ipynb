# %%
headers = {
'User-Agent': 'Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/49.0.2623.221 Safari/537.36 SE 2.X MetaSr 1.0',
'Cookie':'a22e7_readlog=%2C74712%2C74677%2C74702%2C511950%2C512508%2C512506%2C507556%2C98009%2C324939%2C528189%2C; a22e7_ol_offset=139874; a22e7_lastpos=F24; visid_incap_1639104=7ZcAEzlZS7mfFea3pKwCuSHNPlsAAAAAQUIPAAAAAABo69fAFR2DaixTBswbv6AB; incap_ses_895_1639104=+GKeAYKfvRzJ9F6RKK5rDA+3X1sAAAAA4bod2vkkGxglac9Na2Z+BQ==; __tins__19410549=%7B%22sid%22%3A%201532999434044%2C%20%22vd%22%3A%201%2C%20%22expires%22%3A%201533001234044%7D; __51cke__=; __51laig__=3; ZDEDebuggerPresent=php,phtml,php3; a22e7_lastvisit=5192%091532999632%09%2F2048%2Fthread.php%3Ffid-24.html; a22e7_threadlog=%2C243619%2C99985%2C98049%2C98005%2C98047%2C0%2C7%2C21%2C24%2C'}

import requests
import urllib.request 
from bs4 import BeautifulSoup
from urllib.request import urlopen
import myspider
import time
since = time.time()
#url = 'http://www.weiai2048.com/2048/thread.php?fid-21-page-144.html'
#url = 'http://www.weiai2048.com/2048/thread.php?fid-24.html'
subpage_url_num_list = []
for i in range(45,50):
    url = 'http://www.weiai2048.com/2048/thread.php?fid-23-page-'+str(i)+'.html'
    req = urllib.request.Request(url,headers=headers)
    result = urlopen(req)
    soup = BeautifulSoup(result,'html.parser')
    myspider.get_num_list6(soup,subpage_url_num_list)
    subpage_url_num_list = list(set(subpage_url_num_list))

print(subpage_url_num_list)
All_list = []
myspider.open2append('d:\\img\\lib.txt',All_list)
myspider.open2w('d:\\img\\new.txt',subpage_url_num_list,All_list)

print(str(len(subpage_url_num_list))+' get and '+
    str(len(myspider.diff(subpage_url_num_list,All_list)))+ ' new numbers')
print(myspider.diff(subpage_url_num_list,All_list))

All_list=All_list+myspider.diff(subpage_url_num_list,All_list)

myspider.open2w('d:\\img\\lib.txt',All_list)
time_elapsed = time.time() - since
print (time_elapsed)
# Out:
# ['257067', '257053', '253624', '256399', '256396', '256405', '253750', '255154', '257234', '254974', '253803', '253615', '256392', '250430', '253640', '257061', '256984', '258555', '253776', '256428', '258801', '257050', '256938', '257283', '253843', '260632', '257066', '256440', '258774', '254947', '254943', '257076', '250423', '258574', '253801', '257040', '257001', '256411', '258556', '250743', '253571', '256950', '258554', '257310', '257060', '258546', '257300', '257063', '257008', '253756', '257090', '256945', '253878', '256386', '256994', '253711', '257271', '257386', '256417', '257032', '253826', '253832', '257320', '257074', '257293', '257020', '253658', '259624', '257225', '254950', '254972', '253733', '256390', '253852', '253759', '258827', '257068', '250725', '258823', '258760', '257214', '257023', '252997', '257051', '257081', '255159', '254129', '257277', '258751', '257086', '255161', '250434', '256632', '253721', '253635', '258820', '256424', '258742', '255142', '256432
# ...

# %%
headers = {
'User-Agent': 'Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/49.0.2623.221 Safari/537.36 SE 2.X MetaSr 1.0',
'Cookie':'a22e7_readlog=%2C74712%2C74677%2C74702%2C511950%2C512508%2C512506%2C507556%2C98009%2C324939%2C528189%2C; a22e7_ol_offset=139874; a22e7_lastpos=F24; visid_incap_1639104=7ZcAEzlZS7mfFea3pKwCuSHNPlsAAAAAQUIPAAAAAABo69fAFR2DaixTBswbv6AB; incap_ses_895_1639104=+GKeAYKfvRzJ9F6RKK5rDA+3X1sAAAAA4bod2vkkGxglac9Na2Z+BQ==; __tins__19410549=%7B%22sid%22%3A%201532999434044%2C%20%22vd%22%3A%201%2C%20%22expires%22%3A%201533001234044%7D; __51cke__=; __51laig__=3; ZDEDebuggerPresent=php,phtml,php3; a22e7_lastvisit=5192%091532999632%09%2F2048%2Fthread.php%3Ffid-24.html; a22e7_threadlog=%2C243619%2C99985%2C98049%2C98005%2C98047%2C0%2C7%2C21%2C24%2C'}

import requests
import urllib.request 
from bs4 import BeautifulSoup
from urllib.request import urlopen
import myspider, time

image_url_list = []
error_list=[]
num_list =[]
myspider.open2append('d:\\img\\new.txt',num_list)
myspider.open2append('d:\\img\\bu.txt',num_list)
#myspider.open2append('d:\\img\\bu.txt',num_list)

def get_url(num):
    req = urllib.request.Request('http://www.weiai2048.com/2048/read.php?tid-' + num + '.html',headers=headers)
    result = urlopen(req, timeout=45)
    soup2 = BeautifulSoup(result,'html.parser')
    myspider.get_list(soup2,image_url_list)
    print(num +' done')


for num in num_list:
    try:
        since=time.time()
        get_url(num)
        time_elapsed = time.time() - since
        print(str(num_list.index(num))+': '+str(time_elapsed))
    except Exception as e:
        error_list.append(num)

image_url_list = list(set(image_url_list))
print(len(image_url_list))

def open2a(path,l):
    f = open(path , 'a')
    for i in l:
        i = str(i).strip('[').strip(']').replace("'","").replace(' ','')
        f.write(i+'\n')
    f.close()

open2a('d:\\img\\url23.txt',image_url_list)
myspider.open2w('d:\\img\\bu.txt',error_list)
# Out:
# 257067 done
# 0: 21.491999864578247
# 257053 done
# 1: 7.7240002155303955
# 253624 done
# 2: 13.04099988937378
# 256399 done
# 3: 4.067999839782715
# 256396 done
# 4: 8.058000326156616
# 256405 done
# 5: 12.788999795913696
# 253750 done
# 6: 40.948999881744385
# 255154 done
# 7: 9.39400029182434
# 257234 done
# 8: 3.125999927520752
# Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# 254974 done
# 9: 13.114000082015991
# 253803 done
# 10: 6.485999822616577
# 253615 done
# 11: 7.589000225067139
# 256392 done
# 12: 5.417999744415283
# 250430 done
# 13: 13.41700005531311
# 253640 done
# 14: 42.71900010108948
# 257061 done
# 15: 10.983999967575073
# 256984 done
# 16: 4.895999908447266
# 258555 done
# 17: 8.838000059127808
# 253776 done
# 18: 19.61299991607666
# 256428 done
# 19: 10.187999963760376
# 258801 done
# 20: 12.342000007629395
# 257050 done
# 21: 5.7170000076293945
# 256938 done
# 22: 83.95199990272522
# 257283 done
# 23: 5.194000244140625
# ...

# %%
error_list
# Out:
# ['285366', '284439', '279200', '281503', '284445']

# %%
image_url_list = []
myspider.open2append('d:\\img\\url.txt',image_url_list)

def pop_1000():
    for i in range(1000):
        if len(image_url_list)>0:
            print(image_url_list.pop(0))
            
print(len(image_url_list))       
pop_1000()
print(len(image_url_list))
myspider.open2w('d:\\img\\url.txt',image_url_list)

# %%
import time
since = time.time()
time_elapsed = time.time() - since
'{:.0f}m {:.0f}s'.format(time_elapsed // 60, time_elapsed % 60)
